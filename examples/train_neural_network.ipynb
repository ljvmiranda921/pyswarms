# %% [markdown]
# # Training a Neural Network
# In this example, we'll be training a neural network using particle swarm optimization. For this we'll be using the standard global-best PSO `pyswarms.single.GBestPSO` for optimizing the network's weights and biases. This aims to demonstrate how the API is capable of handling custom-defined functions.
#
# For this example, we'll try to classify the three iris species in the Iris Dataset.

# %%
import sys
# Change directory to access the pyswarms module
sys.path.append('../')

# %%
print('Running on Python version: {}'.format(sys.version))
# Out:
# Running on Python version: 3.6.8 |Anaconda, Inc.| (default, Dec 30 2018, 01:22:34)
# [GCC 7.3.0]

# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


# Import PySwarms
import pyswarms as ps

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# First, we'll load the dataset from `scikit-learn`. The Iris Dataset contains 3 classes for each of the iris species (_iris setosa_, _iris virginica_, and _iris versicolor_). It has 50 samples per class with 150 samples in total, making it a very balanced dataset. Each sample is characterized by four features (or dimensions): sepal length, sepal width, petal length, petal width.

# %%
# Load the iris dataset
data = load_iris()

# Store the features as X and the labels as y
X = data.data
y = data.target

# %% [markdown]
# ## Constructing a custom objective function
# Recall that neural networks can simply be seen as a mapping function from one space to another. For now, we'll build a simple neural network with the following characteristics:
# * Input layer size: 4
# * Hidden layer size: 20 (activation: $\tanh(x)$)
# * Output layer size: 3 (activation: $softmax(x)$)
#
# Things we'll do:
# 1. Create a `forward_prop` method that will do forward propagation for one particle.
# 2. Create an overhead objective function `f()` that will compute `forward_prop()` for the whole swarm.

# %% [markdown]
# What we'll be doing then is to create a swarm with a number of dimensions equal to the weights and biases. We will __unroll__ these parameters into an n-dimensional array, and have each particle take on different values. Thus, each particle represents a candidate neural network with its own weights and bias. When feeding back to the network, we will reconstruct the learned weights and biases.
#
# When rolling-back the parameters into weights and biases, it is useful to recall the shape and bias matrices:
# * Shape of input-to-hidden weight matrix: (4, 20)
# * Shape of input-to-hidden bias array: (20, )
# * Shape of hidden-to-output weight matrix: (20, 3)
# * Shape of hidden-to-output bias array: (3, )
#
# By unrolling them together, we have $(4 * 20) + (20 * 3) + 20 + 3 = 163$ parameters, or 163 dimensions for each particle in the swarm.

# %% [markdown]
# The negative log-likelihood will be used to compute for the error between the ground-truth values and the predictions. Also, because PSO doesn't rely on the gradients, we'll not be performing backpropagation (this may be a good thing or bad thing under some circumstances).
#
# Now, let's write the forward propagation procedure as our objective function. Let $X$ be the input, $z_l$ the pre-activation at layer $l$, and $a_l$ the activation for layer $l$:

# %%
# Forward propagation
def forward_prop(params):
    """Forward propagation as objective function
    
    This computes for the forward propagation of the neural network, as
    well as the loss. It receives a set of parameters that must be 
    rolled-back into the corresponding weights and biases.
    
    Inputs
    ------
    params: np.ndarray
        The dimensions should include an unrolled version of the 
        weights and biases.
        
    Returns
    -------
    float
        The computed negative log-likelihood loss given the parameters
    """
    # Neural network architecture
    n_inputs = 4
    n_hidden = 20
    n_classes = 3
    
    # Roll-back the weights and biases
    W1 = params[0:80].reshape((n_inputs,n_hidden))
    b1 = params[80:100].reshape((n_hidden,))
    W2 = params[100:160].reshape((n_hidden,n_classes))
    b2 = params[160:163].reshape((n_classes,))
    
    # Perform forward propagation
    z1 = X.dot(W1) + b1  # Pre-activation in Layer 1
    a1 = np.tanh(z1)     # Activation in Layer 1
    z2 = a1.dot(W2) + b2 # Pre-activation in Layer 2
    logits = z2          # Logits for Layer 2
    
    # Compute for the softmax of the logits
    exp_scores = np.exp(logits)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) 
    
    # Compute for the negative log likelihood
    N = 150 # Number of samples
    corect_logprobs = -np.log(probs[range(N), y])
    loss = np.sum(corect_logprobs) / N
    
    return loss

# %% [markdown]
# Now that we have a method to do forward propagation for one particle (or for one set of dimensions), we can then create a higher-level method to compute `forward_prop()` to the whole swarm:

# %%
def f(x):
    """Higher-level method to do forward_prop in the 
    whole swarm.
    
    Inputs
    ------
    x: numpy.ndarray of shape (n_particles, dimensions)
        The swarm that will perform the search
        
    Returns
    -------
    numpy.ndarray of shape (n_particles, )
        The computed loss for each particle
    """
    n_particles = x.shape[0]
    j = [forward_prop(x[i]) for i in range(n_particles)]
    return np.array(j)

# %% [markdown]
# ## Performing PSO on the custom-function
# Now that everything has been set-up, we just call our global-best PSO and run the optimizer as usual. For now, we'll just set the PSO parameters arbitrarily.

# %%
# %%time
# Initialize swarm
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}

# Call instance of PSO
dimensions = (4 * 20) + (20 * 3) + 20 + 3 
optimizer = ps.single.GlobalBestPSO(n_particles=100, dimensions=dimensions, options=options)

# Perform optimization
cost, pos = optimizer.optimize(f, iters=1000)
# Out:
# 2019-02-21 00:27:43,567 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
# pyswarms.single.global_best:   0%|          |0/1000
# pyswarms.single.global_best:   0%|          |0/1000, best_cost=1.11
# pyswarms.single.global_best:   0%|          |0/1000, best_cost=1.11
# pyswarms.single.global_best:   0%|          |0/1000, best_cost=1.11
# pyswarms.single.global_best:   0%|          |3/1000, best_cost=1.11
# pyswarms.single.global_best:   0%|          |3/1000, best_cost=1.11
# pyswarms.single.global_best:   0%|          |3/1000, best_cost=1.1
# pyswarms.single.global_best:   0%|          |3/1000, best_cost=1.1
# pyswarms.single.global_best:   1%|          |6/1000, best_cost=1.1
# pyswarms.single.global_best:   1%|          |6/1000, best_cost=1.02
# pyswarms.single.global_best:   1%|          |6/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |6/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |9/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |9/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |9/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |9/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |12/1000, best_cost=0.858
# pyswarms.single.global_best:   1%|          |12/1000, best_cost=0.756
# pyswarms.single.global_best:   1%|          |12/1000, best_cost=0.756
# pyswarms.single.global_best:   1%|          |12/1000, best_cost=0.756
# pyswarms.single.global_best:   2%|▏         |15/1000, best_cost=0.756
# pyswarms.single.global_best:   2%|▏         |15/1000, best_cost=0.756
# pyswarms.single.global_best:   2%|▏         |15/1000, best_cost=0.756
# pyswarms.single.global_best:   2%|▏         |15/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |18/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |18/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |18/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |18/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |21/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |21/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |21/1000, best_cost=0.714
# pyswarms.single.global_best:   2%|▏         |21/1000, best_cost=0.711
# pyswarms.single.global_best:   2%|▏         |24/1000, best_cost=0.711
# pyswarms.single.global_best:   2%|▏         |24/1000, best_cost=0.711
# pyswarms.single.global_best:   2%|▏         |24/1000, best_cost=0.711
# pyswarms.single.global_best:   2%|▏         |24/1000, best_cost=0.574
# pyswarms.single.global_best:   3%|▎         |27/1000, best_cost=0.574
# pyswarms.single.global_best:   3%|▎         |27/1000, best_cost=0.574
# pyswarms.single.global_best:   3%|▎         |27/1000, best_cost=0.574
# pyswarms.single.global_best:   3%|▎         |27/1000, best_cost=0.574
# pyswarms.single.global_best:   3%|▎         |30/1000, best_cost=0.574
# pyswarms.single.global_best:   3%|▎         |30/1000, best_cost=0.561
# pyswarms.single.global_best:   3%|▎         |30/1000, best_cost=0.543
# pyswarms.single.global_best:   3%|▎         |30/1000, best_cost=0.543
# pyswarms.single.global_best:   3%|▎         |33/1000, best_cost=0.543
# pyswarms.single.global_best:   3%|▎         |33/1000, best_cost=0.543
# pyswarms.single.global_best:   3%|▎         |33/1000, best_cost=0.543
# pyswarms.single.global_best:   3%|▎         |33/1000, best_cost=0.543
# pyswarms.single.global_best:   4%|▎         |36/1000, best_cost=0.543
# pyswarms.single.global_best:   4%|▎         |36/1000, best_cost=0.543
# pyswarms.single.global_best:   4%|▎         |36/1000, best_cost=0.511
# pyswarms.single.global_best:   4%|▎         |36/1000, best_cost=0.469
# pyswarms.single.global_best:   4%|▍         |39/1000, best_cost=0.469
# pyswarms.single.global_best:   4%|▍         |39/1000, best_cost=0.469
# pyswarms.single.global_best:   4%|▍         |39/1000, best_cost=0.469
# pyswarms.single.global_best:   4%|▍         |39/1000, best_cost=0.469
# pyswarms.single.global_best:   4%|▍         |42/1000, best_cost=0.469
# pyswarms.single.global_best:   4%|▍         |42/1000, best_cost=0.464
# pyswarms.single.global_best:   4%|▍         |42/1000, best_cost=0.447
# pyswarms.single.global_best:   4%|▍         |42/1000, best_cost=0.447
# pyswarms.single.global_best:   4%|▍         |45/1000, best_cost=0.447
# pyswarms.single.global_best:   4%|▍         |45/1000, best_cost=0.447
# pyswarms.single.global_best:   4%|▍         |45/1000, best_cost=0.444
# pyswarms.single.global_best:   4%|▍         |45/1000, best_cost=0.429
# pyswarms.single.global_best:   5%|▍         |48/1000, best_cost=0.429
# pyswarms.single.global_best:   5%|▍         |48/1000, best_cost=0.429
# pyswarms.single.global_best:   5%|▍         |48/1000, best_cost=0.401
# pyswarms.single.global_best:   5%|▍         |48/1000, best_cost=0.401
# pyswarms.single.global_best:   5%|▌         |51/1000, best_cost=0.401
# pyswarms.single.global_best:   5%|▌         |51/1000, best_cost=0.401
# pyswarms.single.global_best:   5%|▌         |51/1000, best_cost=0.396
# pyswarms.single.global_best:   5%|▌         |51/1000, best_cost=0.396
# pyswarms.single.global_best:   5%|▌         |54/1000, best_cost=0.396
# pyswarms.single.global_best:   5%|▌         |54/1000, best_cost=0.395
# pyswarms.single.global_best:   5%|▌         |54/1000, best_cost=0.395
# pyswarms.single.global_best:   5%|▌         |54/1000, best_cost=0.394
# pyswarms.single.global_best:   6%|▌         |57/1000, best_cost=0.394
# pyswarms.single.global_best:   6%|▌         |57/1000, best_cost=0.386
# pyswarms.single.global_best:   6%|▌         |57/1000, best_cost=0.377
# pyswarms.single.global_best:   6%|▌         |57/1000, best_cost=0.334
# pyswarms.single.global_best:   6%|▌         |60/1000, best_cost=0.334
# pyswarms.single.global_best:   6%|▌         |60/1000, best_cost=0.334
# pyswarms.single.global_best:   6%|▌         |60/1000, best_cost=0.334
# pyswarms.single.global_best:   6%|▌         |60/1000, best_cost=0.327
# pyswarms.single.global_best:   6%|▋         |63/1000, best_cost=0.327
# pyswarms.single.global_best:   6%|▋         |63/1000, best_cost=0.316
# pyswarms.single.global_best:   6%|▋         |63/1000, best_cost=0.31
# pyswarms.single.global_best:   6%|▋         |63/1000, best_cost=0.305
# pyswarms.single.global_best:   7%|▋         |66/1000, best_cost=0.305
# pyswarms.single.global_best:   7%|▋         |66/1000, best_cost=0.302
# pyswarms.single.global_best:   7%|▋         |66/1000, best_cost=0.296
# pyswarms.single.global_best:   7%|▋         |66/1000, best_cost=0.287
# pyswarms.single.global_best:   7%|▋         |69/1000, best_cost=0.287
# pyswarms.single.global_best:   7%|▋         |69/1000, best_cost=0.287
# pyswarms.single.global_best:   7%|▋         |69/1000, best_cost=0.287
# pyswarms.single.global_best:   7%|▋         |69/1000, best_cost=0.286
# pyswarms.single.global_best:   7%|▋         |72/1000, best_cost=0.286
# pyswarms.single.global_best:   7%|▋         |72/1000, best_cost=0.28
# pyswarms.single.global_best:   7%|▋         |72/1000, best_cost=0.274
# pyswarms.single.global_best:   7%|▋         |72/1000, best_cost=0.269
# pyswarms.single.global_best:   8%|▊         |75/1000, best_cost=0.269
# pyswarms.single.global_best:   8%|▊         |75/1000, best_cost=0.269
# pyswarms.single.global_best:   8%|▊         |75/1000, best_cost=0.268
# pyswarms.single.global_best:   8%|▊         |75/1000, best_cost=0.266
# pyswarms.single.global_best:   8%|▊         |78/1000, best_cost=0.266
# pyswarms.single.global_best:   8%|▊         |78/1000, best_cost=0.264
# pyswarms.single.global_best:   8%|▊         |78/1000, best_cost=0.261
# pyswarms.single.global_best:   8%|▊         |78/1000, best_cost=0.234
# pyswarms.single.global_best:   8%|▊         |81/1000, best_cost=0.234
# pyswarms.single.global_best:   8%|▊         |81/1000, best_cost=0.226
# pyswarms.single.global_best:   8%|▊         |81/1000, best_cost=0.21
# pyswarms.single.global_best:   8%|▊         |81/1000, best_cost=0.185
# pyswarms.single.global_best:   8%|▊         |84/1000, best_cost=0.185
# pyswarms.single.global_best:   8%|▊         |84/1000, best_cost=0.169
# pyswarms.single.global_best:   8%|▊         |84/1000, best_cost=0.166
# pyswarms.single.global_best:   8%|▊         |84/1000, best_cost=0.162
# pyswarms.single.global_best:   9%|▊         |87/1000, best_cost=0.162
# pyswarms.single.global_best:   9%|▊         |87/1000, best_cost=0.151
# pyswarms.single.global_best:   9%|▊         |87/1000, best_cost=0.151
# pyswarms.single.global_best:   9%|▊         |87/1000, best_cost=0.132
# pyswarms.single.global_best:   9%|▉         |90/1000, best_cost=0.132
# pyswarms.single.global_best:   9%|▉         |90/1000, best_cost=0.114
# pyswarms.single.global_best:   9%|▉         |90/1000, best_cost=0.111
# pyswarms.single.global_best:   9%|▉         |90/1000, best_cost=0.111
# pyswarms.single.global_best:   9%|▉         |93/1000, best_cost=0.111
# pyswarms.single.global_best:   9%|▉         |93/1000, best_cost=0.101
# pyswarms.single.global_best:   9%|▉         |93/1000, best_cost=0.0902
# pyswarms.single.global_best:   9%|▉         |93/1000, best_cost=0.0862
# pyswarms.single.global_best:  10%|▉         |96/1000, best_cost=0.0862
# pyswarms.single.global_best:  10%|▉         |96/1000, best_cost=0.0855
# pyswarms.single.global_best:  10%|▉         |96/1000, best_cost=0.0821
# pyswarms.single.global_best:  10%|▉         |96/1000, best_cost=0.0814
# pyswarms.single.global_best:  10%|▉         |99/1000, best_cost=0.0814
# pyswarms.single.global_best:  10%|▉         |99/1000, best_cost=0.0814
# pyswarms.single.global_best:  10%|▉         |99/1000, best_cost=0.0814
# pyswarms.single.global_best:  10%|▉         |99/1000, best_cost=0.0811
# pyswarms.single.global_best:  10%|█         |102/1000, best_cost=0.0811
# pyswarms.single.global_best:  10%|█         |102/1000, best_cost=0.0778
# pyswarms.single.global_best:  10%|█         |102/1000, best_cost=0.0778
# pyswarms.single.global_best:  10%|█         |102/1000, best_cost=0.0778
# pyswarms.single.global_best:  10%|█         |105/1000, best_cost=0.0778
# pyswarms.single.global_best:  10%|█         |105/1000, best_cost=0.0718
# pyswarms.single.global_best:  10%|█         |105/1000, best_cost=0.0718
# pyswarms.single.global_best:  10%|█         |105/1000, best_cost=0.0718
# pyswarms.single.global_best:  11%|█         |108/1000, best_cost=0.0718
# pyswarms.single.global_best:  11%|█         |108/1000, best_cost=0.0714
# pyswarms.single.global_best:  11%|█         |108/1000, best_cost=0.0695
# pyswarms.single.global_best:  11%|█         |108/1000, best_cost=0.0695
# pyswarms.single.global_best:  11%|█         |111/1000, best_cost=0.0695
# pyswarms.single.global_best:  11%|█         |111/1000, best_cost=0.0694
# pyswarms.single.global_best:  11%|█         |111/1000, best_cost=0.0694
# pyswarms.single.global_best:  11%|█         |111/1000, best_cost=0.0689
# pyswarms.single.global_best:  11%|█▏        |114/1000, best_cost=0.0689
# pyswarms.single.global_best:  11%|█▏        |114/1000, best_cost=0.0689
# pyswarms.single.global_best:  11%|█▏        |114/1000, best_cost=0.0676
# pyswarms.single.global_best:  11%|█▏        |114/1000, best_cost=0.0676
# pyswarms.single.global_best:  12%|█▏        |117/1000, best_cost=0.0676
# pyswarms.single.global_best:  12%|█▏        |117/1000, best_cost=0.0676
# pyswarms.single.global_best:  12%|█▏        |117/1000, best_cost=0.0676
# pyswarms.single.global_best:  12%|█▏        |117/1000, best_cost=0.0676
# pyswarms.single.global_best:  12%|█▏        |120/1000, best_cost=0.0676
# pyswarms.single.global_best:  12%|█▏        |120/1000, best_cost=0.0664
# pyswarms.single.global_best:  12%|█▏        |120/1000, best_cost=0.0664
# pyswarms.single.global_best:  12%|█▏        |120/1000, best_cost=0.0664
# pyswarms.single.global_best:  12%|█▏        |123/1000, best_cost=0.0664
# pyswarms.single.global_best:  12%|█▏        |123/1000, best_cost=0.0664
# pyswarms.single.global_best:  12%|█▏        |123/1000, best_cost=0.0664
# pyswarms.single.global_best:  12%|█▏        |123/1000, best_cost=0.0647
# pyswarms.single.global_best:  13%|█▎        |126/1000, best_cost=0.0647
# pyswarms.single.global_best:  13%|█▎        |126/1000, best_cost=0.0647
# pyswarms.single.global_best:  13%|█▎        |126/1000, best_cost=0.0647
# pyswarms.single.global_best:  13%|█▎        |126/1000, best_cost=0.0647
# pyswarms.single.global_best:  13%|█▎        |129/1000, best_cost=0.0647
# pyswarms.single.global_best:  13%|█▎        |129/1000, best_cost=0.0644
# pyswarms.single.global_best:  13%|█▎        |129/1000, best_cost=0.0637
# pyswarms.single.global_best:  13%|█▎        |129/1000, best_cost=0.0635
# pyswarms.single.global_best:  13%|█▎        |132/1000, best_cost=0.0635
# pyswarms.single.global_best:  13%|█▎        |132/1000, best_cost=0.0626
# pyswarms.single.global_best:  13%|█▎        |132/1000, best_cost=0.0614
# pyswarms.single.global_best:  13%|█▎        |132/1000, best_cost=0.0605
# pyswarms.single.global_best:  14%|█▎        |135/1000, best_cost=0.0605
# pyswarms.single.global_best:  14%|█▎        |135/1000, best_cost=0.06
# pyswarms.single.global_best:  14%|█▎        |135/1000, best_cost=0.0596
# pyswarms.single.global_best:  14%|█▎        |135/1000, best_cost=0.0592
# pyswarms.single.global_best:  14%|█▍        |138/1000, best_cost=0.0592
# pyswarms.single.global_best:  14%|█▍        |138/1000, best_cost=0.0572
# pyswarms.single.global_best:  14%|█▍        |138/1000, best_cost=0.0572
# pyswarms.single.global_best:  14%|█▍        |138/1000, best_cost=0.0569
# pyswarms.single.global_best:  14%|█▍        |141/1000, best_cost=0.0569
# pyswarms.single.global_best:  14%|█▍        |141/1000, best_cost=0.0556
# pyswarms.single.global_best:  14%|█▍        |141/1000, best_cost=0.0556
# pyswarms.single.global_best:  14%|█▍        |141/1000, best_cost=0.0553
# pyswarms.single.global_best:  14%|█▍        |144/1000, best_cost=0.0553
# pyswarms.single.global_best:  14%|█▍        |144/1000, best_cost=0.0548
# pyswarms.single.global_best:  14%|█▍        |144/1000, best_cost=0.0545
# pyswarms.single.global_best:  14%|█▍        |144/1000, best_cost=0.0534
# pyswarms.single.global_best:  15%|█▍        |147/1000, best_cost=0.0534
# pyswarms.single.global_best:  15%|█▍        |147/1000, best_cost=0.0524
# pyswarms.single.global_best:  15%|█▍        |147/1000, best_cost=0.0517
# pyswarms.single.global_best:  15%|█▍        |147/1000, best_cost=0.0511
# pyswarms.single.global_best:  15%|█▌        |150/1000, best_cost=0.0511
# pyswarms.single.global_best:  15%|█▌        |150/1000, best_cost=0.0505
# pyswarms.single.global_best:  15%|█▌        |150/1000, best_cost=0.0495
# pyswarms.single.global_best:  15%|█▌        |150/1000, best_cost=0.049
# pyswarms.single.global_best:  15%|█▌        |153/1000, best_cost=0.049
# pyswarms.single.global_best:  15%|█▌        |153/1000, best_cost=0.0485
# pyswarms.single.global_best:  15%|█▌        |153/1000, best_cost=0.0484
# pyswarms.single.global_best:  15%|█▌        |153/1000, best_cost=0.0475
# pyswarms.single.global_best:  16%|█▌        |156/1000, best_cost=0.0475
# pyswarms.single.global_best:  16%|█▌        |156/1000, best_cost=0.0472
# pyswarms.single.global_best:  16%|█▌        |156/1000, best_cost=0.0462
# pyswarms.single.global_best:  16%|█▌        |156/1000, best_cost=0.0462
# pyswarms.single.global_best:  16%|█▌        |159/1000, best_cost=0.0462
# pyswarms.single.global_best:  16%|█▌        |159/1000, best_cost=0.0457
# pyswarms.single.global_best:  16%|█▌        |159/1000, best_cost=0.0452
# pyswarms.single.global_best:  16%|█▌        |159/1000, best_cost=0.0449
# pyswarms.single.global_best:  16%|█▌        |162/1000, best_cost=0.0449
# pyswarms.single.global_best:  16%|█▌        |162/1000, best_cost=0.0447
# pyswarms.single.global_best:  16%|█▌        |162/1000, best_cost=0.0443
# pyswarms.single.global_best:  16%|█▌        |162/1000, best_cost=0.0442
# pyswarms.single.global_best:  16%|█▋        |165/1000, best_cost=0.0442
# pyswarms.single.global_best:  16%|█▋        |165/1000, best_cost=0.0442
# pyswarms.single.global_best:  16%|█▋        |165/1000, best_cost=0.0442
# pyswarms.single.global_best:  16%|█▋        |165/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |168/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |168/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |168/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |168/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |171/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |171/1000, best_cost=0.0439
# pyswarms.single.global_best:  17%|█▋        |171/1000, best_cost=0.0438
# pyswarms.single.global_best:  17%|█▋        |171/1000, best_cost=0.0438
# pyswarms.single.global_best:  17%|█▋        |174/1000, best_cost=0.0438
# pyswarms.single.global_best:  17%|█▋        |174/1000, best_cost=0.0438
# pyswarms.single.global_best:  17%|█▋        |174/1000, best_cost=0.0436
# pyswarms.single.global_best:  17%|█▋        |174/1000, best_cost=0.0435
# pyswarms.single.global_best:  18%|█▊        |177/1000, best_cost=0.0435
# pyswarms.single.global_best:  18%|█▊        |177/1000, best_cost=0.0432
# pyswarms.single.global_best:  18%|█▊        |177/1000, best_cost=0.043
# pyswarms.single.global_best:  18%|█▊        |177/1000, best_cost=0.043
# pyswarms.single.global_best:  18%|█▊        |180/1000, best_cost=0.043
# pyswarms.single.global_best:  18%|█▊        |180/1000, best_cost=0.043
# pyswarms.single.global_best:  37%|███▋      |372/1000, best_cost=0.038
# pyswarms.single.global_best:  37%|███▋      |372/1000, best_cost=0.038
# pyswarms.single.global_best:  38%|███▊      |375/1000, best_cost=0.038
# pyswarms.single.global_best:  38%|███▊      |375/1000, best_cost=0.0379
# pyswarms.single.global_best:  38%|███▊      |375/1000, best_cost=0.0379
# pyswarms.single.global_best:  38%|███▊      |375/1000, best_cost=0.0379
# pyswarms.single.global_best:  38%|███▊      |378/1000, best_cost=0.0379
# pyswarms.single.global_best:  38%|███▊      |378/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |378/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |378/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |381/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |381/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |381/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |381/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |384/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |384/1000, best_cost=0.0378
# pyswarms.single.global_best:  38%|███▊      |384/1000, best_cost=0.0377
# pyswarms.single.global_best:  38%|███▊      |384/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▊      |387/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▊      |387/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▊      |387/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▊      |387/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▉      |390/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▉      |390/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▉      |390/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▉      |390/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▉      |393/1000, best_cost=0.0377
# pyswarms.single.global_best:  39%|███▉      |393/1000, best_cost=0.0376
# pyswarms.single.global_best:  39%|███▉      |393/1000, best_cost=0.0376
# pyswarms.single.global_best:  39%|███▉      |393/1000, best_cost=0.0376
# pyswarms.single.global_best:  40%|███▉      |396/1000, best_cost=0.0376
# pyswarms.single.global_best:  40%|███▉      |396/1000, best_cost=0.0376
# pyswarms.single.global_best:  40%|███▉      |396/1000, best_cost=0.0376
# pyswarms.single.global_best:  40%|███▉      |396/1000, best_cost=0.0376
# pyswarms.single.global_best:  40%|███▉      |399/1000, best_cost=0.0376
# pyswarms.single.global_best:  40%|███▉      |399/1000, best_cost=0.0375
# pyswarms.single.global_best:  40%|███▉      |399/1000, best_cost=0.0375
# pyswarms.single.global_best:  40%|███▉      |399/1000, best_cost=0.0375
# pyswarms.single.global_best:  40%|████      |402/1000, best_cost=0.0375
# pyswarms.single.global_best:  40%|████      |402/1000, best_cost=0.0375
# pyswarms.single.global_best:  40%|████      |402/1000, best_cost=0.0374
# pyswarms.single.global_best:  40%|████      |402/1000, best_cost=0.0374
# pyswarms.single.global_best:  40%|████      |405/1000, best_cost=0.0374
# pyswarms.single.global_best:  89%|████████▉ |894/1000, best_cost=0.0256
# pyswarms.single.global_best:  89%|████████▉ |894/1000, best_cost=0.0256
# pyswarms.single.global_best:  89%|████████▉ |894/1000, best_cost=0.0255
# pyswarms.single.global_best:  89%|████████▉ |894/1000, best_cost=0.0255
# pyswarms.single.global_best:  90%|████████▉ |897/1000, best_cost=0.0255
# pyswarms.single.global_best:  90%|████████▉ |897/1000, best_cost=0.0255
# pyswarms.single.global_best:  90%|████████▉ |897/1000, best_cost=0.0255
# pyswarms.single.global_best:  90%|████████▉ |897/1000, best_cost=0.0255
# pyswarms.single.global_best:  90%|█████████ |900/1000, best_cost=0.0255
# pyswarms.single.global_best:  90%|█████████ |900/1000, best_cost=0.0254
# pyswarms.single.global_best:  90%|█████████ |900/1000, best_cost=0.0254
# pyswarms.single.global_best:  90%|█████████ |900/1000, best_cost=0.0254
# pyswarms.single.global_best:  90%|█████████ |903/1000, best_cost=0.0254
# pyswarms.single.global_best:  90%|█████████ |903/1000, best_cost=0.0254
# pyswarms.single.global_best:  90%|█████████ |903/1000, best_cost=0.0254
# pyswarms.single.global_best:  90%|█████████ |903/1000, best_cost=0.0254
# pyswarms.single.global_best:  91%|█████████ |906/1000, best_cost=0.0254
# pyswarms.single.global_best:  91%|█████████ |906/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |906/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |906/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |909/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |909/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |909/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |909/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |912/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |912/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |912/1000, best_cost=0.0253
# pyswarms.single.global_best:  91%|█████████ |912/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|915/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|915/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|915/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|915/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|918/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|918/1000, best_cost=0.0253
# pyswarms.single.global_best:  92%|█████████▏|918/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|920/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|920/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|920/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|920/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|923/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|923/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|923/1000, best_cost=0.0252
# pyswarms.single.global_best:  92%|█████████▏|923/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|926/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|926/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|926/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|926/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|929/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|929/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|929/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|929/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|932/1000, best_cost=0.0252
# pyswarms.single.global_best:  93%|█████████▎|932/1000, best_cost=0.0251
# pyswarms.single.global_best:  93%|█████████▎|932/1000, best_cost=0.0251
# pyswarms.single.global_best:  93%|█████████▎|932/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▎|935/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▎|935/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▎|935/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▎|935/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▍|938/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▍|938/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▍|938/1000, best_cost=0.0251
# pyswarms.single.global_best:  94%|█████████▍|938/1000, best_cost=0.025
# pyswarms.single.global_best:  94%|█████████▍|941/1000, best_cost=0.025
# pyswarms.single.global_best:  94%|█████████▍|941/1000, best_cost=0.025
# pyswarms.single.global_best:  94%|█████████▍|941/1000, best_cost=0.025
# pyswarms.single.global_best:  94%|█████████▍|941/1000, best_cost=0.0249
# pyswarms.single.global_best:  94%|█████████▍|944/1000, best_cost=0.0249
# pyswarms.single.global_best:  94%|█████████▍|944/1000, best_cost=0.0249
# pyswarms.single.global_best:  94%|█████████▍|944/1000, best_cost=0.0249
# pyswarms.single.global_best:  94%|█████████▍|944/1000, best_cost=0.0249
# pyswarms.single.global_best:  95%|█████████▍|947/1000, best_cost=0.0249
# pyswarms.single.global_best:  95%|█████████▍|947/1000, best_cost=0.0248
# pyswarms.single.global_best:  95%|█████████▍|947/1000, best_cost=0.0248
# pyswarms.single.global_best:  95%|█████████▍|947/1000, best_cost=0.0247
# pyswarms.single.global_best:  95%|█████████▌|950/1000, best_cost=0.0247
# pyswarms.single.global_best:  95%|█████████▌|950/1000, best_cost=0.0247
# pyswarms.single.global_best:  95%|█████████▌|950/1000, best_cost=0.0246
# pyswarms.single.global_best:  95%|█████████▌|950/1000, best_cost=0.0246
# pyswarms.single.global_best:  95%|█████████▌|953/1000, best_cost=0.0246
# pyswarms.single.global_best:  95%|█████████▌|953/1000, best_cost=0.0245
# pyswarms.single.global_best:  95%|█████████▌|953/1000, best_cost=0.0245
# pyswarms.single.global_best:  95%|█████████▌|953/1000, best_cost=0.0244
# pyswarms.single.global_best:  96%|█████████▌|956/1000, best_cost=0.0244
# pyswarms.single.global_best:  96%|█████████▌|956/1000, best_cost=0.0244
# pyswarms.single.global_best:  96%|█████████▌|956/1000, best_cost=0.0242
# pyswarms.single.global_best:  96%|█████████▌|956/1000, best_cost=0.0241
# pyswarms.single.global_best:  96%|█████████▌|959/1000, best_cost=0.0241
# pyswarms.single.global_best:  96%|█████████▌|959/1000, best_cost=0.024
# pyswarms.single.global_best:  96%|█████████▌|959/1000, best_cost=0.024
# pyswarms.single.global_best:  96%|█████████▌|959/1000, best_cost=0.0239
# pyswarms.single.global_best:  96%|█████████▌|962/1000, best_cost=0.0239
# pyswarms.single.global_best:  96%|█████████▌|962/1000, best_cost=0.0238
# pyswarms.single.global_best:  96%|█████████▌|962/1000, best_cost=0.0237
# pyswarms.single.global_best:  96%|█████████▌|962/1000, best_cost=0.0235
# pyswarms.single.global_best:  96%|█████████▋|965/1000, best_cost=0.0235
# pyswarms.single.global_best:  96%|█████████▋|965/1000, best_cost=0.0234
# pyswarms.single.global_best:  96%|█████████▋|965/1000, best_cost=0.0233
# pyswarms.single.global_best:  96%|█████████▋|965/1000, best_cost=0.0232
# pyswarms.single.global_best:  97%|█████████▋|968/1000, best_cost=0.0232
# pyswarms.single.global_best:  97%|█████████▋|968/1000, best_cost=0.0231
# pyswarms.single.global_best:  97%|█████████▋|968/1000, best_cost=0.023
# pyswarms.single.global_best:  97%|█████████▋|968/1000, best_cost=0.023
# pyswarms.single.global_best:  97%|█████████▋|971/1000, best_cost=0.023
# pyswarms.single.global_best:  97%|█████████▋|971/1000, best_cost=0.0229
# pyswarms.single.global_best:  97%|█████████▋|971/1000, best_cost=0.0229
# pyswarms.single.global_best:  97%|█████████▋|971/1000, best_cost=0.0228
# pyswarms.single.global_best:  97%|█████████▋|974/1000, best_cost=0.0228
# pyswarms.single.global_best:  97%|█████████▋|974/1000, best_cost=0.0227
# pyswarms.single.global_best:  97%|█████████▋|974/1000, best_cost=0.0227
# pyswarms.single.global_best:  97%|█████████▋|974/1000, best_cost=0.0226
# pyswarms.single.global_best:  98%|█████████▊|977/1000, best_cost=0.0226
# pyswarms.single.global_best:  98%|█████████▊|977/1000, best_cost=0.0225
# pyswarms.single.global_best:  98%|█████████▊|977/1000, best_cost=0.0224
# pyswarms.single.global_best:  98%|█████████▊|977/1000, best_cost=0.0224
# pyswarms.single.global_best:  98%|█████████▊|980/1000, best_cost=0.0224
# pyswarms.single.global_best:  98%|█████████▊|980/1000, best_cost=0.0223
# pyswarms.single.global_best:  98%|█████████▊|980/1000, best_cost=0.0222
# pyswarms.single.global_best:  98%|█████████▊|980/1000, best_cost=0.0221
# pyswarms.single.global_best:  98%|█████████▊|983/1000, best_cost=0.0221
# pyswarms.single.global_best:  98%|█████████▊|983/1000, best_cost=0.022
# pyswarms.single.global_best:  98%|█████████▊|983/1000, best_cost=0.0218
# pyswarms.single.global_best:  98%|█████████▊|983/1000, best_cost=0.0217
# pyswarms.single.global_best:  99%|█████████▊|986/1000, best_cost=0.0217
# pyswarms.single.global_best:  99%|█████████▊|986/1000, best_cost=0.0217
# pyswarms.single.global_best:  99%|█████████▊|986/1000, best_cost=0.0215
# pyswarms.single.global_best:  99%|█████████▊|986/1000, best_cost=0.0214
# pyswarms.single.global_best:  99%|█████████▉|989/1000, best_cost=0.0214
# pyswarms.single.global_best:  99%|█████████▉|989/1000, best_cost=0.0213
# pyswarms.single.global_best:  99%|█████████▉|989/1000, best_cost=0.0211
# pyswarms.single.global_best:  99%|█████████▉|989/1000, best_cost=0.021
# pyswarms.single.global_best:  99%|█████████▉|992/1000, best_cost=0.021
# pyswarms.single.global_best:  99%|█████████▉|992/1000, best_cost=0.0208
# pyswarms.single.global_best:  99%|█████████▉|992/1000, best_cost=0.0207
# pyswarms.single.global_best:  99%|█████████▉|992/1000, best_cost=0.0206
# pyswarms.single.global_best: 100%|█████████▉|995/1000, best_cost=0.0206
# pyswarms.single.global_best: 100%|█████████▉|995/1000, best_cost=0.0205
# pyswarms.single.global_best: 100%|█████████▉|995/1000, best_cost=0.0204
# pyswarms.single.global_best: 100%|█████████▉|995/1000, best_cost=0.0203
# pyswarms.single.global_best: 100%|█████████▉|998/1000, best_cost=0.0203
# pyswarms.single.global_best: 100%|█████████▉|998/1000, best_cost=0.0202
# pyswarms.single.global_best: 100%|█████████▉|998/1000, best_cost=0.02
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0.022019-02-21 00:28:22,653 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.020041729812793008, best pos: [ 1.08771946e+00  7.11133974e-01  3.49816679e-01 -5.15260472e-01
#  -5.04285435e-01 -5.94890493e-01 -3.20771251e-02  5.42505842e-01
#   6.34519288e-02 -7.54568643e-01 -1.82706173e-01  8.98189196e-02
#   3.44773133e-01  2.82439069e+00  2.01339522e-01 -9.94306947e-03
#   6.93239970e-01 -1.74873638e-01  1.39945260e+01  1.87507767e-02
#   1.09725949e-01  1.32167588e+00  7.27420261e-02 -9.15005659e-01
#  -2.97645432e+00  3.04014408e-01  4.38244602e-01  1.88063719e-01
#  -1.09021636e-01  9.95701030e-01  1.57691999e+00 -1.22545095e+00
#  -2.38197781e-02 -1.07316119e-01  9.52329765e-01  3.76675896e-01
#  -1.41278146e+00 -7.90104464e-01  1.15779324e-01 -2.72805149e-01
#  -2.36578507e-01 -1.67620802e+00 -9.69971782e-01 -5.25158746e-02
#   4.45172764e-01  4.88523881e-01 -4.96092799e-01  5.64238542e-01
#  -5.57032051e-01  4.59860716e-02  7.98022143e-01  2.63526542e-02
#  -5.88529431e-01 -1.60498347e+00 -1.60409741e+00 -1.99860781e-01
#   1.38265543e-02  1.70699052e+00 -3.84055053e-01 -9.22276464e-02
#   1.00826342e+00 -8.61520218e-02 -5.90428333e-02 -1.00483692e+00
#   6.24682819e-01  1.15070902e-01 -8.61366431e-01 -2.14462501e+00
#   7.71802292e-02  2.59878134e+00 -4.01639164e-01  2.17666938e+00
#  -1.84899210e-01  3.11949208e-01 -1.15821923e+00  2.83903060e-01
#   5.04962573e-01 -8.73052212e-01 -4.93416158e+01  6.41416100e-01
#  -1.62689013e+00 -9.05961168e-01  5.26334563e-01 -3.32853419e-01
#  -2.12934936e+00 -2.45048780e-01  2.41256447e+00 -4.98079665e-01
#  -1.29125591e-01 -4.88232730e-01 -5.73982473e-02  1.80920417e+00
#   1.34522599e-01  3.46773811e-01  7.09585677e-01  1.38391247e-01
#  -2.57840963e-01  1.55336291e-01  2.00574234e-01 -2.30765402e-01
#  -1.70227432e-01  7.62878734e-01  9.90102765e-01  1.08992068e+00
#   1.29864801e+00 -2.39028256e+01  4.08607749e-01 -1.33929562e+00
#  -4.42173850e-01 -2.90708584e-01 -3.31690235e+00 -3.24833534e-01
#   5.69226453e-01 -7.56417939e-01  2.35462895e+01 -1.25258037e+00
#   6.43687804e+00  4.47718914e-01  1.24557217e-01  4.65645280e-01
#  -1.68572336e+01 -3.95185175e-01  5.54466334e-01  6.20247034e-01
#   4.61257125e-01 -5.42173496e-01  4.86800625e-01 -1.03161781e+00
#   1.94137384e-01  9.22961395e-01  2.59821560e-01  7.50306886e-01
#  -3.07663812e+00 -1.72669441e+00  6.89933562e-01 -5.84154003e-02
#   1.21161265e+00 -1.87334031e-02 -8.29659805e-01 -4.77415109e-01
#   2.58009089e-01  1.66848451e-01  9.25833860e-01  4.24067577e-01
#   5.45591182e-01  3.38551880e-01 -1.30342906e+00  3.53282766e-01
#  -9.38728075e-01 -5.54385157e-01  7.30952641e-02 -1.16200094e+01
#   5.25882919e-02 -3.43024513e+00  1.66186745e-01  7.88828957e-01
#  -4.37870106e+00 -3.91453585e-01  1.69316098e+01 -1.10453990e+00
#   1.06919502e-01 -6.91731290e-01  5.11340090e-01]
# CPU times: user 29.2 s, sys: 900 ms, total: 30.1 s
# Wall time: 39.1 s

# %% [markdown]
# ## Checking the accuracy
# We can then check the accuracy by performing forward propagation once again to create a set of predictions. Then it's only a simple matter of matching which one's correct or not. For the `logits`, we take the `argmax`. Recall that the softmax function returns probabilities where the whole vector sums to 1. We just take the one with the highest probability then treat it as the network's prediction.
#
# Moreover, we let the best position vector found by the swarm be the weight and bias parameters of the network.

# %%
def predict(X, pos):
    """
    Use the trained weights to perform class predictions.
    
    Inputs
    ------
    X: numpy.ndarray
        Input Iris dataset
    pos: numpy.ndarray
        Position matrix found by the swarm. Will be rolled
        into weights and biases.
    """
    # Neural network architecture
    n_inputs = 4
    n_hidden = 20
    n_classes = 3
    
    # Roll-back the weights and biases
    W1 = pos[0:80].reshape((n_inputs,n_hidden))
    b1 = pos[80:100].reshape((n_hidden,))
    W2 = pos[100:160].reshape((n_hidden,n_classes))
    b2 = pos[160:163].reshape((n_classes,))
    
    # Perform forward propagation
    z1 = X.dot(W1) + b1  # Pre-activation in Layer 1
    a1 = np.tanh(z1)     # Activation in Layer 1
    z2 = a1.dot(W2) + b2 # Pre-activation in Layer 2
    logits = z2          # Logits for Layer 2
    
    y_pred = np.argmax(logits, axis=1)
    return y_pred

# %% [markdown]
# And from this we can just compute for the accuracy. We perform predictions, compare an equivalence to the ground-truth value `y`, and get the mean.

# %%
(predict(X, pos) == y).mean()
# Out:
# 0.9866666666666667
